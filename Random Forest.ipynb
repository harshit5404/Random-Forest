# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
bank = pd.read_csv('bank (1).csv')

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# # Data Overview

# %%
bank.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
bank['job'].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
bank.shape
# Out:
# (4521, 17)

# %%
bank['marital'].value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
bank['job'].value_counts().values
# Out:
# array([969, 946, 768, 478, 417, 230, 183, 168, 128, 112,  84,  38],
#       dtype=int64)

# %%
bank['job'].value_counts().keys()
# Out:
# Index(['management', 'blue-collar', 'technician', 'admin.', 'services',
#        'retired', 'self-employed', 'entrepreneur', 'unemployed', 'housemaid',
#        'student', 'unknown'],
#       dtype='object')

# %% [markdown]
# # Exploratory data Analysis

# %%
sns.pairplot(bank,hue='y')

# %%
sns.distplot(bank['age'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bank['job'].value_counts().keys()[0:5]),list(bank['job'].value_counts()[0:5]),color=['blue','orange','red','green','yellow'])
# Out:
# <BarContainer object of 5 artists>

# %%
bank['marital'].value_counts().keys()
# Out:
# Index(['married', 'single', 'divorced'], dtype='object')

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bank['marital'].value_counts().keys()[0:5]),list(bank['marital'].value_counts()[0:5]),color=['red','green','yellow'])
# Out:
# <BarContainer object of 3 artists>

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank['education'].value_counts().keys()
# Out:
# Index(['secondary', 'tertiary', 'primary', 'unknown'], dtype='object')

# %%
bank['education'].value_counts()
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bank['education'].value_counts().keys()[0:5]),list(bank['education'].value_counts()[0:5]),color=['black','brown','pink','blue'])
# Out:
# <BarContainer object of 4 artists>

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
plt.figure(figsize=(10,5))
plt.hist(bank['balance'],bins=3)
# Out:
# (array([4.504e+03, 1.600e+01, 1.000e+00]),
#  array([-3313.        , 21520.66666667, 46354.33333333, 71188.        ]),
#  <BarContainer object of 3 artists>)

# %%
bank['loan'].value_counts(),bank.shape
# Out:
# (no     3830
#  yes     691
#  Name: loan, dtype: int64,
#  (4521, 17))

# %%
plt.bar(list(bank['loan'].value_counts().keys()),list(bank['loan'].value_counts()),color=['grey','pink'])
# Out:
# <BarContainer object of 2 artists>

# %%
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# # Separating out the dependent and independent columns

# %%
x = bank[['age']]

# %%
y = bank[['balance']]

# %% [markdown]
# # Splitting dataset into train and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=(0.3))

# %% [markdown]
# # Applying RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfg = RandomForestRegressor()

# %%
rfg.fit(x_train,y_train)
# Out:
# C:\Users\meghna tyagi\AppData\Local\Temp\ipykernel_8588\2097697493.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfg.fit(x_train,y_train)
# RandomForestRegressor()

# %%
y_pred=rfg.predict(x_test)

# %%
y_test.head(),y_pred[0:5]
# Out:
# (      balance
#  420      1076
#  2792      478
#  314       760
#  2911        0
#  2259      326,
#  array([1189.45758888, 1236.66462535, 1479.03228084, 1125.997976  ,
#         1505.56327745]))

# %% [markdown]
# # Applying Meansquarederror

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 9499778.609913131
